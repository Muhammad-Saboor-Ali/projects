# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("spam.csv",encoding="latin-1")

# %%
df.sample(5)
# Out:
#       target  ...                                   transformed_text
# 2071       0  ...             good night dear sleepwel amp take care
# 1052       0  ...  got anoth job one hospit data analysi someth s...
# 143        0  ...                                  know pl open back
# 4833       0  ...                                hope pee burn tonit
# 669        0  ...                                       u receiv msg
#
# [5 rows x 6 columns]

# %%
df.shape
# Out:
# (5572, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
df.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'],inplace=True)

# %%
df.sample(5)
# Out:
#        v1                                                 v2
# 4942  ham  Check mail.i have mailed varma and kept copy t...
# 5525  ham  I want to tell you how bad I feel that basical...
# 776   ham  Why don't you go tell your friend you're not s...
# 4870  ham                Well. You know what i mean. Texting
# 1836  ham                             Are you wet right now?

# %%
df.rename(columns={'v1':'target','v2':'text'},inplace=True)

# %%
df
# Out:
#      target                                               text
# 0       ham  Go until jurong point, crazy.. Available only ...
# 1       ham                      Ok lar... Joking wif u oni...
# 2      spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       ham  U dun say so early hor... U c already then say...
# 4       ham  Nah I don't think he goes to usf, he lives aro...
# ...     ...                                                ...
# 5567   spam  This is the 2nd time we have tried 2 contact u...
# 5568    ham              Will Ì_ b going to esplanade fr home?
# 5569    ham  Pity, * was in mood for that. So...any other s...
# 5570    ham  The guy did some bitching but I acted like i'd...
# 5571    ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
df['target'].unique()
# Out:
# array([0, 1])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['target'] = le.fit_transform(df['target'])

# %%
df['target']
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 5567    1
# 5568    0
# 5569    0
# 5570    0
# 5571    0
# Name: target, Length: 5572, dtype: int64

# %%
df.isnull().sum()
# Out:
# target              0
# text                0
# num_characters      0
# num_words           0
# num_sent            0
# transformed_text    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(403)

# %%
df = df.drop_duplicates(keep='first')

# %%
df.shape
# Out:
# (5169, 2)

# %%
df['target'].value_counts()
# Out:
# target
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(df['target'].value_counts(),labels=['ham','spam'],autopct='%0.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x2a9349db7d0>,
#   <matplotlib.patches.Wedge at 0x2a934971e80>],
#  [Text(-1.014499732282844, 0.4251944181172162, 'ham'),
#   Text(1.0144998708287172, -0.42519408755122207, 'spam')],
#  [Text(-0.5533634903360967, 0.2319242280639361, '87.37'),
#   Text(0.553363565906573, -0.231924047755212, '12.63')])

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (3.9.4)
# Requirement already satisfied: click in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from nltk) (8.3.3)
# Requirement already satisfied: joblib in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from nltk) (2026.5.9)
# Requirement already satisfied: tqdm in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from click->nltk) (0.4.6)
# [notice] A new release of pip is available: 23.2.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
df['num_characters'] = df['text'].apply(len)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_14868\253964734.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num_characters'] = df['text'].apply(len)

# %%
df['num_words'] = df['text'].apply(lambda x:len(nltk.word_tokenize(x)))
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_14868\76344806.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num_words'] = df['text'].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
df['num_sent'] = df['text'].apply(lambda x:len(nltk.sent_tokenize(x)))
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_14868\1110724051.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num_sent'] = df['text'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df
# Out:
#       target                                               text  num_characters  num_words  num_sent
# 0          0  Go until jurong point, crazy.. Available only ...             111         24         2
# 1          0                      Ok lar... Joking wif u oni...              29          8         2
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...             155         37         2
# 3          0  U dun say so early hor... U c already then say...              49         13         1
# 4          0  Nah I don't think he goes to usf, he lives aro...              61         15         1
# ...      ...                                                ...             ...        ...       ...
# 5567       1  This is the 2nd time we have tried 2 contact u...             161         35         4
# 5568       0              Will Ì_ b going to esplanade fr home?              37          9         1
# 5569       0  Pity, * was in mood for that. So...any other s...              57         15         2
# 5570       0  The guy did some bitching but I acted like i'd...             125         27         1
# 5571       0                         Rofl. Its true to its name              26          7         2
#
# [5169 rows x 5 columns]

# %%
df[df['target'] == 0][['num_characters','num_words','num_sent']].describe()
# Out:
#        num_characters    num_words     num_sent
# count     4516.000000  4516.000000  4516.000000
# mean        70.459256    17.123782     1.820195
# std         56.358207    13.493970     1.383657
# min          2.000000     1.000000     1.000000
# 25%         34.000000     8.000000     1.000000
# 50%         52.000000    13.000000     1.000000
# 75%         90.000000    22.000000     2.000000
# max        910.000000   220.000000    38.000000

# %%
df[df['target'] == 1][['num_characters','num_words','num_sent']].describe()
# Out:
#        num_characters   num_words    num_sent
# count      653.000000  653.000000  653.000000
# mean       137.891271   27.667688    2.970904
# std         30.137753    7.008418    1.488425
# min         13.000000    2.000000    1.000000
# 25%        132.000000   25.000000    2.000000
# 50%        149.000000   29.000000    3.000000
# 75%        157.000000   32.000000    4.000000
# max        224.000000   46.000000    9.000000

# %%
import seaborn as sns

# %%
sns.histplot(df[df['target'] == 0]['num_characters'])
sns.histplot(df[df['target'] == 1]['num_characters'],color='red')
# Out:
# <Axes: xlabel='num_characters', ylabel='Count'>

# %%
sns.histplot(df[df['target'] == 0]['num_words'])
sns.histplot(df[df['target'] == 1]['num_words'],color='red')
# Out:
# <Axes: xlabel='num_words', ylabel='Count'>

# %%
sns.histplot(df[df['target'] == 0]['num_sent'])
sns.histplot(df[df['target'] == 1]['num_sent'],color='red')
# Out:
# <Axes: xlabel='num_sent', ylabel='Count'>

# %%
sns.pairplot(df,hue='target')

# %%
df
# Out:
#       target                                               text  num_characters  num_words  num_sent
# 0          0  Go until jurong point, crazy.. Available only ...             111         24         2
# 1          0                      Ok lar... Joking wif u oni...              29          8         2
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...             155         37         2
# 3          0  U dun say so early hor... U c already then say...              49         13         1
# 4          0  Nah I don't think he goes to usf, he lives aro...              61         15         1
# ...      ...                                                ...             ...        ...       ...
# 5567       1  This is the 2nd time we have tried 2 contact u...             161         35         4
# 5568       0              Will Ì_ b going to esplanade fr home?              37          9         1
# 5569       0  Pity, * was in mood for that. So...any other s...              57         15         2
# 5570       0  The guy did some bitching but I acted like i'd...             125         27         1
# 5571       0                         Rofl. Its true to its name              26          7         2
#
# [5169 rows x 5 columns]

# %%
df.corr(numeric_only=True)
# Out:
#                   target  num_characters  num_words  num_sent
# target          1.000000        0.384717   0.262912  0.263939
# num_characters  0.384717        1.000000   0.965760  0.624139
# num_words       0.262912        0.965760   1.000000  0.679971
# num_sent        0.263939        0.624139   0.679971  1.000000

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
df['text'] = df['text'].str.lower()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_14868\474617635.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['text'].str.lower()

# %%
df
# Out:
#       target                                               text  num_characters  num_words  num_sent
# 0          0  go until jurong point, crazy.. available only ...             111         24         2
# 1          0                      ok lar... joking wif u oni...              29          8         2
# 2          1  free entry in 2 a wkly comp to win fa cup fina...             155         37         2
# 3          0  u dun say so early hor... u c already then say...              49         13         1
# 4          0  nah i don't think he goes to usf, he lives aro...              61         15         1
# ...      ...                                                ...             ...        ...       ...
# 5567       1  this is the 2nd time we have tried 2 contact u...             161         35         4
# 5568       0              will ì_ b going to esplanade fr home?              37          9         1
# 5569       0  pity, * was in mood for that. so...any other s...              57         15         2
# 5570       0  the guy did some bitching but i acted like i'd...             125         27         1
# 5571       0                         rofl. its true to its name              26          7         2
#
# [5169 rows x 5 columns]

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
import string
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def transform_text(text):
    text = text.lower()
    text = nltk.word_tokenize(text)
    
    y = []
    for i in text:
        if i.isalnum():
            y.append(i)
    
    text = y[:]
    y.clear()
    
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)
            
    text = y[:]
    y.clear()
    
    for i in text:
        y.append(ps.stem(i))
    
            
    return " ".join(y)

# %%
df['transformed_text'] = df['text'].apply(transform_text)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_14868\283536690.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['transformed_text'] = df['text'].apply(transform_text)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tf = TfidfVectorizer(max_features=3000)

# %%
x = tf.fit_transform(df['transformed_text']).toarray()

# %%
x.shape
# Out:
# (5169, 3000)

# %%
y = df['target'].values

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB,BernoulliNB,MultinomialNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()

# %%
# gnb.fit(x_train,y_train)
# y_pred1 = gnb.predict(x_test)
# print(accuracy_score(y_test,y_pred1))
# print(confusion_matrix(y_test,y_pred1))
# print(precision_score(y_test,y_pred1))
# Out:
# 0.874274661508704
# [[790 106]
#  [ 24 114]]
# 0.5181818181818182

# %%
mnb.fit(x_train,y_train)
y_pred1 = mnb.predict(x_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.9709864603481625
# [[896   0]
#  [ 30 108]]
# 1.0

# %%
# bnb.fit(x_train,y_train)
# y_pred1 = bnb.predict(x_test)
# print(accuracy_score(y_test,y_pred1))
# print(confusion_matrix(y_test,y_pred1))
# print(precision_score(y_test,y_pred1))
# Out:
# 0.9835589941972921
# [[895   1]
#  [ 16 122]]
# 0.991869918699187

# %%
# from sklearn.tree import DecisionTreeClassifier

# %%
# dtc = DecisionTreeClassifier()

# %%
# dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
# y_pred1 = dtc.predict(x_test)
# print(accuracy_score(y_test,y_pred1))
# print(confusion_matrix(y_test,y_pred1))
# print(precision_score(y_test,y_pred1))
# Out:
# 0.9516441005802708
# [[868  28]
#  [ 22 116]]
# 0.8055555555555556

# %%
import pickle
pickle.dump(tf,open('vectorizer.pkl','wb'))
pickle.dump(mnb,open('model.pkl','wb'))
